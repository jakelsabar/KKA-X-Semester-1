# %% [markdown]
# <a href="https://colab.research.google.com/github/jakelsabar/KKA-X-Semester-1/blob/main/2_Tipe_Variable_Nazril_Zakaria_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama = Nazril Zakaria
#
# Kelas = X - 11
#
# No. Absen = 24

# %% [markdown]
# #Konsep Dasar Variable

# %%
print("jakelsabar@gmail.com")
print("jakelsabar@gmail.com")
print("jakelsabar@gmail.com")
# Out:
# jakelsabar@gmail.com
# jakelsabar@gmail.com
# jakelsabar@gmail.com

# %%
email_user_1 = "jakelsabar@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# jakelsabar@gmail.com
# jakelsabar@gmail.com
# jakelsabar@gmail.com

# %% [markdown]
# #Peraturan Penamaan Variabel

# %%
#Hanya diperbolehkan Menggunakan huruf, angka, dan underscore
email user 2 = "jakelsabar@gmail.com"

print(email user 2)
# Out:
#   File "/tmp/ipython-input-1560232284.py", line 2
#     email user 2 = "jakelsabar@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh didahului oleh angka
3_email_user = "jakelsabar@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-1564069319.py", line 2
#     3_email_user = "jakelsabar@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "jakelsabar@gmail.com"

print(email_user_3)
# Out:
# jakelsabar@gmail.com

# %%
#Tidak boleh menggunakan kata kunci python
for = "jakelsabar@gmail.com"

print(for)
# Out:
#   File "/tmp/ipython-input-2587800784.py", line 2
#     for = "jakelsabar@gmail.com"
#         ^
# SyntaxError: invalid syntax

# %%
For = "jakelsabar@gmail.com"

print(For)
# Out:
# jakelsabar@gmail.com

# %%
print = "jakelsabar@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3350464569.py in <cell line: 0>()
#       1 print = "jakelsabar@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "jakelsabar@gmail.com"

print(Print)
# Out:
# jakelsabar@gmail.com

# %%
#Tidak error tapi dianjurkan harus deskriptif
_ = "jakelsabar@gmail.com"

# %%
print(_)
# Out:
# jakelsabar@gmail.com

# %%
_ = "jakelsabar@gmail.com"

# %%
print(_)
# Out:
# jakelsabar@gmail.com

# %% [markdown]
# #Assignment

# %%
#Single assigment
nama_mahasiswa_1 =  "Alexandrio"

print(nama_mahasiswa_1
# Out:
#   File "/tmp/ipython-input-339721516.py", line 4
#     print(nama_mahasiswa_1
#                           ^
# SyntaxError: incomplete input

# %%
#Multiple Assignment

# nama_barang_1 = "rinso"
# nama_barang_2 = "molto"

nama_barang_1, nama_barang_2 = "rinso", "molto"
print(nama_barang_1)
print(nama_barang_2)
# Out:
# rinso
# molto

# %%
#Assignment yang sama
nilai_devandra = nilai_willy = nilai_dzakki = 100

print(nilai_devandra)
print(nilai_willy)
print(nilai_dzakki)
# Out:
# 100
# 100
# 100

# %%
# Menimpa/Mengubah Nilai Variable

nilai_himam = 95

# %%
print(nilai_himam)
# Out:
# 95

# %%
nilai_himam = 100

# %%
print(nilai_himam)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2701357047.py in <cell line: 0>()
# ----> 1 print(nilai_himam)
#
# NameError: name 'nilai_himam' is not defined

# %% [markdown]
# #Penggunaan Operator di Python

# %%
#tanpa variabel
print(20 + 3)
# Out:
# 23

# %%
#operand disimpan kedalam variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

print(roti_swiss_alex + roti_swiss_nazril)
# Out:
# 23

# %%
#hasil operasi disimpan ke dalam variabel
jumlah_roti_swiss = 20+3

print(jumlah_roti_swiss)
# Out:
# 23

# %%
#operand dan hasil operasi disimpan ke variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

jumlah_roti_swiss = roti_swiss_alex + roti_swiss_nazril

print(jumlah_roti_swiss)
# Out:
# 23

# %% [markdown]
# #Tugas

# %%
print(24 * 3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus * jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

total_jumlah_botol = banyak_botol_per_kardus * jumlah_kardus

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Operator Aritmatika

# %%
buku_tulis_himam = 55
buku_tulis_vico = 15

# %%
#Penjumlahan
total_buku_tulis = buku_tulis_himam + buku_tulis_vico
print(total_buku_tulis)
# Out:
# 70

# %%
#Pengurangan

selisih_buku_tulis = buku_tulis_himam - buku_tulis_vico
print(selisih_buku_tulis)
# Out:
# 40

# %%
#Perkalian
jumlah_kardus_buku_tulis = 3
isi_buku_tulis_perkardus = 10

total_buku_tulis = jumlah_kardus_buku_tulis * isi_buku_tulis_perkardus
print(total_buku_tulis)
# Out:
# 30

# %%
#Pembagian
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis / jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3.3333333333333335

# %%
#Pembagian bulat
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis // jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3

# %%
#sisa bagi

sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
print(sisa_buku_tulis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3924379233.py in <cell line: 0>()
#       1 #sisa bagi
#       2
# ----> 3 sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
#       4 print(sisa_buku_tulis)
#
# NameError: name 'total_buku_tulis' is not defined

# %% [markdown]
# #Operator Perbandingan

# %%
print(6 >= 6)
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print(8 < 10)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5 <= 5))
# Out:
# False

# %%
print(8 > 7 and 6 < 5)
# Out:
# False

# %%
print(7 <= 1 or 2 != 2)
# Out:
# False

# %%
print(not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print(not(5 < 10 or 5 <= 10))
# Out:
# False
